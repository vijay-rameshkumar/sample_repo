# %%
import pandas as pd

# %%
panelist_flattened_df = pd.read_csv('data/target_group_transformed_small.csv')
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (62,67,69,70,71,72,73,74,75) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(panelist_flattened_df)
# Out:
#       supplier_sample_pulls__created_at  \
# 0              2022-03-18T07:09:18.919Z
# 1              2022-04-02T02:03:12.043Z
# 2              2022-04-02T02:03:12.043Z
# 3              2022-04-02T02:03:12.043Z
# 4              2022-04-02T02:03:12.043Z
# ...                                 ...
# 14698          2022-04-22T22:25:19.517Z
# 14699          2022-04-22T22:25:19.517Z
# 14700          2022-04-22T22:25:19.517Z
# 14701          2022-04-22T22:25:19.517Z
# 14702          2022-04-22T22:25:19.517Z
#
#       supplier_sample_pulls__sampling_method  \
# 0                                 integrated
# 1                                 integrated
# 2                                 integrated
# 3                                 integrated
# 4                                 integrated
# ...                                      ...
# 14698                             integrated
# 14699                             integrated
# 14700                             integrated
# ...

# %%
print(panelist_flattened_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14703 entries, 0 to 14702
# Data columns (total 76 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   supplier_sample_pulls__created_at          14703 non-null  object
#  1   supplier_sample_pulls__sampling_method     14703 non-null  object
#  2   sample_pulls__target_groups                14703 non-null  object
#  3   sample_pulls__country                      14703 non-null  object
#  4   sample_pulls__language                     14703 non-null  object
#  5   sample_pulls__cost_per_interview           14703 non-null  float64
#  6   sample_pulls__incident_rate                14703 non-null  float64
#  7   sample_pulls__length_of_interview          14703 non-null  int64
#  8   sample_pulls__completes_needed             14703 non-null  int64
#  9   sample_pulls__start_date                   14703 non-null  object
# ...

# %%
print(panelist_flattened_df.corr())
# Out:
#                                            sample_pulls__cost_per_interview  \
# sample_pulls__cost_per_interview                                   1.000000
# sample_pulls__incident_rate                                       -0.169556
# sample_pulls__length_of_interview                                 -0.022618
# sample_pulls__completes_needed                                    -0.024884
# suppliers__tier                                                   -0.008704
# suppliers__ref                                                    -0.125916
# suppliers__is_integrated_sampling_enabled                         -0.047991
# suppliers__is_default                                             -0.047991
# work_orders__length_of_interview                                  -0.022618
# work_orders__bid_target                                            0.013703
# work_orders__has_programming_requirements                          0.170138
# ...

# %%
import matplotlib.pyplot as plt
panelist_flattened_df.plot()
plt.show()

# %%
panelist_flattened_subset = panelist_flattened_df[['projects__study_types_ids', 'projects__study_types_subject_ids',
'projects__target_groups_name','projects__target_groups_qualifications','GENDER','AGE','STANDARD_JOB_TITLE',
'STANDARD_B2B_DECISION_MAKER','STANDARD_INDUSTRY_PERSONAL','STANDARD_EMPLOYMENT','STANDARD_NO_OF_EMPLOYEES']]
panelist_flattened_subset.head(50)
# Out:
#    projects__study_types_ids   projects__study_types_subject_ids  \
# 0                        B2B               ['banking_financial']
# 1                        B2B               ['banking_financial']
# 2                        B2B               ['banking_financial']
# 3                        B2B               ['banking_financial']
# 4                        B2B               ['banking_financial']
# 5                        B2B               ['banking_financial']
# 6                        B2B               ['banking_financial']
# 7                        B2B               ['banking_financial']
# 8                        B2B               ['banking_financial']
# 9                        B2B               ['banking_financial']
# 10                       B2B               ['banking_financial']
# 11                       B2B               ['banking_financial']
# 12                       B2B    ['service', 'software_hardware']
# ...

# %%
entertainment_df = pd.read_csv('data/subjectwise_transformed_small_dfs/dfs/entertainment.csv')
household_df = pd.read_csv('data/subjectwise_transformed_small_dfs/dfs/household.csv')
it_decision_maker_df = pd.read_csv('data/subjectwise_transformed_small_dfs/dfs/it_decision_maker.csv')
other_df = pd.read_csv('data/subjectwise_transformed_small_dfs/dfs/other.csv')
software_hardware_df = pd.read_csv('data/subjectwise_transformed_small_dfs/dfs/software_hardware.csv')

# %%
short_df = pd.read_csv('data/subjectwise_transformed_small_dfs/dfs/short.csv')
short_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2506 entries, 0 to 2505
# Data columns (total 59 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   supplier_sample_pulls__created_at               2506 non-null   object
#  1   supplier_sample_pulls__sampling_method          2506 non-null   object
#  2   sample_pulls__target_groups                     2506 non-null   object
#  3   sample_pulls__country                           2506 non-null   object
#  4   sample_pulls__language                          2506 non-null   object
#  5   sample_pulls__cost_per_interview                2506 non-null   float64
#  6   sample_pulls__incident_rate                     2506 non-null   float64
#  7   sample_pulls__length_of_interview               2506 non-null   int64
#  8   sample_pulls__completes_needed                  2506 non-null   int64
# ...

# %%
other_df = pd.read_csv('data/subjectwise_transformed_small_dfs/dfs/other.csv')
other_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 67 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   supplier_sample_pulls__created_at               3309 non-null   object
#  1   supplier_sample_pulls__sampling_method          3309 non-null   object
#  2   sample_pulls__target_groups                     3309 non-null   object
#  3   sample_pulls__country                           3309 non-null   object
#  4   sample_pulls__language                          3309 non-null   object
#  5   sample_pulls__cost_per_interview                3309 non-null   float64
#  6   sample_pulls__incident_rate                     3309 non-null   float64
#  7   sample_pulls__length_of_interview               3309 non-null   int64
#  8   sample_pulls__completes_needed                  3309 non-null   int64
# ...

# %%
household_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 63 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   supplier_sample_pulls__created_at               1218 non-null   object
#  1   supplier_sample_pulls__sampling_method          1218 non-null   object
#  2   sample_pulls__target_groups                     1218 non-null   object
#  3   sample_pulls__country                           1218 non-null   object
#  4   sample_pulls__language                          1218 non-null   object
#  5   sample_pulls__cost_per_interview                1218 non-null   float64
#  6   sample_pulls__incident_rate                     1218 non-null   float64
#  7   sample_pulls__length_of_interview               1218 non-null   int64
#  8   sample_pulls__completes_needed                  1218 non-null   int64
# ...

# %%
it_decision_maker_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 60 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   supplier_sample_pulls__created_at               807 non-null    object
#  1   supplier_sample_pulls__sampling_method          807 non-null    object
#  2   sample_pulls__target_groups                     807 non-null    object
#  3   sample_pulls__country                           807 non-null    object
#  4   sample_pulls__language                          807 non-null    object
#  5   sample_pulls__cost_per_interview                807 non-null    float64
#  6   sample_pulls__incident_rate                     807 non-null    float64
#  7   sample_pulls__length_of_interview               807 non-null    int64
#  8   sample_pulls__completes_needed                  807 non-null    int64
# ...

# %%
software_hardware_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 56 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   supplier_sample_pulls__created_at               535 non-null    object
#  1   supplier_sample_pulls__sampling_method          535 non-null    object
#  2   sample_pulls__target_groups                     535 non-null    object
#  3   sample_pulls__country                           535 non-null    object
#  4   sample_pulls__language                          535 non-null    object
#  5   sample_pulls__cost_per_interview                535 non-null    float64
#  6   sample_pulls__incident_rate                     535 non-null    float64
#  7   sample_pulls__length_of_interview               535 non-null    int64
#  8   sample_pulls__completes_needed                  535 non-null    int64
# ...

# %%
entertainment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1237 entries, 0 to 1236
# Data columns (total 61 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   supplier_sample_pulls__created_at               1237 non-null   object
#  1   supplier_sample_pulls__sampling_method          1237 non-null   object
#  2   sample_pulls__target_groups                     1237 non-null   object
#  3   sample_pulls__country                           1237 non-null   object
#  4   sample_pulls__language                          1237 non-null   object
#  5   sample_pulls__cost_per_interview                1237 non-null   float64
#  6   sample_pulls__incident_rate                     1237 non-null   float64
#  7   sample_pulls__length_of_interview               1237 non-null   int64
#  8   sample_pulls__completes_needed                  1237 non-null   int64
# ...
