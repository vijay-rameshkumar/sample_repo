# %%
import pandas as pd
import numpy as np

# %%
DATAPATH = 'data/subjectwise_transformed_small_dfs/dfs/other.csv' 

df = pd.read_csv(DATAPATH)
#df = df[~df.overview.isna()]
df.rename(columns={'projects__target_groups_qualifications_combine':'sentence'}, inplace=True)
print(len(df))
#df = df.iloc[:20000]
df.head()
# Out:
# 3309
#   supplier_sample_pulls__created_at supplier_sample_pulls__sampling_method  \
# 0          2022-04-21T22:56:13.751Z                                 manual
# 1          2022-04-21T22:56:13.751Z                                 manual
# 2          2022-04-21T22:56:13.751Z                                 manual
# 3          2022-04-21T22:56:13.751Z                                 manual
# 4          2022-04-21T22:56:13.751Z                                 manual
#
#                          sample_pulls__target_groups sample_pulls__country  \
# 0  [{"name": "Welding", "quota": 150, "qualificat...                   usa
# 1  [{"name": "Welding", "quota": 150, "qualificat...                   usa
# 2  [{"name": "Welding", "quota": 150, "qualificat...                   usa
# 3  [{"name": "Welding", "quota": 150, "qualificat...                   usa
# 4  [{"name": "Welding", "quota": 150, "qualificat...                   usa
#
#   sample_pulls__language  sample_pulls__cost_per_interview  \
# 0                    eng                              17.5
# 1                    eng                              17.5
# 2                    eng                              17.5
# 3                    eng                              17.5
# 4                    eng                              17.5
#
#    sample_pulls__incident_rate  sample_pulls__length_of_interview  \
# 0                          0.3                                  8
# 1                          0.3                                  8
# 2                          0.3                                  8
# 3                          0.3                                  8
# 4                          0.3                                  8
#
#    sample_pulls__completes_needed sample_pulls__start_date  ...  \
# 0                             150               2022-04-21  ...
# 1                             150               2022-04-21  ...
# 2                             150               2022-04-21  ...
# 3                             150               2022-04-21  ...
# 4                             150               2022-04-21  ...
#
#                   qualifications_STANDARD_EMPLOYMENT  \
# 0  ['Self-employed part-time', 'Self-employed ful...
# 1  ['Self-employed part-time', 'Self-employed ful...
# 2  ['Self-employed part-time', 'Self-employed ful...
# 3  ['Self-employed part-time', 'Self-employed ful...
# 4  ['Self-employed part-time', 'Self-employed ful...
#
#   qualifications_STANDARD_JOB_TITLE qualifications_AGE  \
# 0                               NaN                NaN
# 1                               NaN                NaN
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                               NaN                NaN
#
#   qualifications_STANDARD_NO_OF_EMPLOYEES  qualifications_STATE  \
# 0                                     NaN                   NaN
# 1                                     NaN                   NaN
# 2                                     NaN                   NaN
# 3                                     NaN                   NaN
# 4                                     NaN                   NaN
#
#    qualifications_ZIP  qualifications_GENDER  qualifications_DMA  \
# 0                 NaN                    NaN                 NaN
# 1                 NaN                    NaN                 NaN
# 2                 NaN                    NaN                 NaN
# 3                 NaN                    NaN                 NaN
# 4                 NaN                    NaN                 NaN
#
#   qualifications_PROVINCE_OR_TERRITORY_OF_CANADA  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   qualifications_STANDARD_COMPANY_REVENUE
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 67 columns]

# %%
df = df[['rl','projects__name','sentence']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rl              3309 non-null   int64
#  1   projects__name  3309 non-null   object
#  2   sentence        3309 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 77.7+ KB

# %% [markdown]
# # Data Processing/Cleaning

# %%
import nltk
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

#STOPWORDS = set(stopwords.words('english'))
MIN_WORDS = 4
MAX_WORDS = 200
'''
PATTERN_S = re.compile("\'s")  # matches `'s` from text  
PATTERN_RN = re.compile("\\r\\n") #matches `\r` and `\n`
PATTERN_PUNC = re.compile(r"[^\w\s]") # matches all non 0-9 A-z whitespace 

def clean_text(text):
    """
    Series of cleaning. String to lower case, remove non words characters and numbers.
        text (str): input text
    return (str): modified initial text
    """
    text = text.lower()  # lowercase text
    text = re.sub(PATTERN_S, ' ', text)
    text = re.sub(PATTERN_RN, ' ', text)
    text = re.sub(PATTERN_PUNC, ' ', text)
    return text

def tokenizer(sentence, min_words=MIN_WORDS, max_words=MAX_WORDS, stopwords=STOPWORDS, lemmatize=False):
    """
    Lemmatize, tokenize, crop and remove stop words.
    """
    if lemmatize:
        stemmer = WordNetLemmatizer()
        tokens = [stemmer.lemmatize(w) for w in word_tokenize(sentence)]
    else:
        tokens = [w for w in word_tokenize(sentence)]
    token = [w for w in tokens if (len(w) > min_words and len(w) < max_words
                                                        and w not in stopwords)]
    return tokens    
'''
def tokenizer(sentence, min_words=MIN_WORDS, max_words=MAX_WORDS, stopwords=None, lemmatize=False):
    """
    Lemmatize, tokenize, crop and remove stop words.
    """
    
    tokens = [w for w in word_tokenize(sentence)]
    print(tokens)
    '''
    token = [w for w in tokens if (len(w) > min_words and len(w) < max_words
                                                        and w not in stopwords)]
    '''
    return tokens

def clean_sentences(df):
    """
    Remove irrelavant characters (in new column clean_sentence).
    Lemmatize, tokenize words into list of words (in new column tok_lem_sentence).
    """
    print('Cleaning sentences...')
    #df['clean_sentence'] = df['sentence'].apply(clean_text)
    df['tok_lem_sentence'] = df['sentence'].apply(
        lambda x: tokenizer(x, min_words=MIN_WORDS, max_words=MAX_WORDS, stopwords=None, lemmatize=True))
    return df
    
df = clean_sentences(df)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\junaid.shaikh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Cleaning sentences...
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ['{', "'STANDARD_B2B_DECISION_MAKER", "'", ':', '[', "'Other", "'", ',', "'Office", 'supplies', "'", ',', "'Operations", "'", ']', ',', "'STANDARD_INDUSTRY_PERSONAL", "'", ':', '[', "'Shipping\\\\/Distribution", "'", ',', "'Carpenting\\\\/Electrical", 'installations\\\\/VVS', "'", ',', "'Transportation", "'", ',', "'Automotive", "'", ',', "'Engineering", "'", ',', "'Construction", "'", ',', "'Energy\\\\/Utilities\\\\/Oil", 'and', 'Gas', "'", ',', "'Chemicals\\\\/Plastics\\\\/Rubber", "'", ',', "'Aviation", "'", ']', ',', "'STANDARD_EMPLOYMENT", "'", ':', '[', "'Self-employed", 'part-time', "'", ',', "'Self-employed", 'full-time', "'", ',', "'Employed", 'part-time', "'", ',', "'Employed", 'full-time', "'", ']', '}']
# ...
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'STATE", "'", ':', '[', "'MASSACHUSETTS", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'AGE", "'", ':', '[', "'18-99", "'", ']', '}']

# %%
print(len(df))
print(df.head())
print(df.info())
#df[['sentence', 'clean_sentence', 'tok_lem_sentence']]
# Out:
# 3309
#     rl projects__name                                           sentence  \
# 0  528  Welding Study  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 1  528  Welding Study  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 2  528  Welding Study  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 3  528  Welding Study  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 4  528  Welding Study  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
#
#                                     tok_lem_sentence
# 0  [{, 'STANDARD_B2B_DECISION_MAKER, ', :, [, 'Ot...
# 1  [{, 'STANDARD_B2B_DECISION_MAKER, ', :, [, 'Ot...
# 2  [{, 'STANDARD_B2B_DECISION_MAKER, ', :, [, 'Ot...
# 3  [{, 'STANDARD_B2B_DECISION_MAKER, ', :, [, 'Ot...
# 4  [{, 'STANDARD_B2B_DECISION_MAKER, ', :, [, 'Ot...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rl                3309 non-null   int64
#  1   projects__name    3309 non-null   object
#  2   sentence          3309 non-null   object
#  3   tok_lem_sentence  3309 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 103.5+ KB
# None

# %%
query_sentence = "STANDARD_JOB_TITLE': ['Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)']"
pd.options.display.max_colwidth = 500

# %%
def extract_best_indices(m, topk, mask=None):
    """
    Use sum of the cosine distance over all tokens.
    m (np.array): cos matrix of shape (nb_in_tokens, nb_dict_tokens)
    topk (int): number of indices to return (from high to lowest in order)
    """
    # return the sum on all tokens of cosinus for each sentence
    if len(m.shape) > 1:
        cos_sim = np.mean(m, axis=0) 
    else: 
        cos_sim = m
    index = np.argsort(cos_sim)[::-1] # from highest idx to smallest score 
    if mask is not None:
        assert mask.shape == m.shape
        mask = mask[index]
    else:
        mask = np.ones(len(cos_sim))
    mask = np.logical_or(cos_sim[index] != 0, mask) #eliminate 0 cosine distance
    best_index = index[mask][:topk]  
    return best_index

# %% [markdown]
# # Tfidf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Adapt stop words
#token_stop = tokenizer(' '.join(STOPWORDS), lemmatize=False)

# Fit TFIDF
#vectorizer = TfidfVectorizer(stop_words=token_stop, tokenizer=tokenizer)
vectorizer = TfidfVectorizer(stop_words=None, tokenizer=tokenizer) 
tfidf_mat = vectorizer.fit_transform(df['sentence'].values) # -> (num_sentences, num_vocabulary)
tfidf_mat.shape
# Out:
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ['{', "'standard_b2b_decision_maker", "'", ':', '[', "'other", "'", ',', "'office", 'supplies', "'", ',', "'operations", "'", ']', ',', "'standard_industry_personal", "'", ':', '[', "'shipping\\\\/distribution", "'", ',', "'carpenting\\\\/electrical", 'installations\\\\/vvs', "'", ',', "'transportation", "'", ',', "'automotive", "'", ',', "'engineering", "'", ',', "'construction", "'", ',', "'energy\\\\/utilities\\\\/oil", 'and', 'gas', "'", ',', "'chemicals\\\\/plastics\\\\/rubber", "'", ',', "'aviation", "'", ']', ',', "'standard_employment", "'", ':', '[', "'self-employed", 'part-time', "'", ',', "'self-employed", 'full-time', "'", ',', "'employed", 'part-time', "'", ',', "'employed", 'full-time', "'", ']', '}']
# ...
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'22-65", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'state", "'", ':', '[', "'massachusetts", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'30-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# ['{', "'age", "'", ':', '[', "'18-99", "'", ']', '}']
# (3309, 138)

# %%
def get_recommendations_tfidf(sentence, tfidf_mat):
    
    """
    Return the database sentences in order of highest cosine similarity relatively to each 
    token of the target sentence. 
    """
    # Embed the query sentence
    tokens = [str(tok) for tok in tokenizer(sentence)]
    vec = vectorizer.transform(tokens)
    # Create list with similarity between query and dataset
    mat = cosine_similarity(vec, tfidf_mat)
    # Best cosine distance for each token independantly
    print(mat.shape)
    best_index = extract_best_indices(mat, topk=10)
    return best_index


best_index = get_recommendations_tfidf(query_sentence, tfidf_mat)

display(df[['rl','projects__name','sentence']].iloc[best_index])
# Out:
# ['STANDARD_JOB_TITLE', "'", ':', '[', "'Owner", ',', 'Partner', ',', 'President', "'", ',', "'Director", '(', 'Group', 'Director', ',', 'Sr.', 'Director', ',', 'Director', ')', "'", ']']
# ['standard_job_title']
# ["'"]
# [':']
# ['[']
# ["'owner"]
# [',']
# ['partner']
# [',']
# ['president']
# ["'"]
# [',']
# ["'director"]
# ['(']
# ['group']
# ['director']
# [',']
# ['sr', '.']
# ['director']
# [',']
# ['director']
# [')']
# ["'"]
# [']']
# (23, 3309)
#        rl               projects__name  \
# 137   273  Product DMs/Business Elites
# 181   273  Product DMs/Business Elites
# 550   500  Product DMs/Business Elites
# 554   500  Product DMs/Business Elites
# 185   273  Product DMs/Business Elites
# 558   500  Product DMs/Business Elites
# 1437  273  Product DMs/Business Elites
# 562   500  Product DMs/Business Elites
# 566   500  Product DMs/Business Elites
# 586   500  Product DMs/Business Elites
#
#                                                                                                                                                    sentence
# 137   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 181   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 550   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 554   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 185   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 558   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 1437  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 562   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 566   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 586   {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}

# %% [markdown]
# # Spacy

# %%
import spacy

# !python -m spacy download en_core_web_lg

#Load pre-trained model
nlp = spacy.load("en_core_web_lg") 
# Apply the model to the sentences
df['spacy_sentence'] = df['sentence'].apply(lambda x: nlp(x)) 
# Retrieve the embedded vectors as a matrix 
embed_mat = df['spacy_sentence'].values
embed_mat.shape
# Out:
# (3309,)

# %%
def predict_spacy(model, query_sentence, embed_mat, topk=10):
    """
    Predict the topk sentences after applying spacy model.
    """
    query_embed = model(query_sentence)
    mat = np.array([query_embed.similarity(line) for line in embed_mat])
    # keep if vector has a norm
    mat_mask = np.array(
        [True if line.vector_norm else False for line in embed_mat])
    best_index_2 = extract_best_indices(mat, topk=topk, mask=mat_mask)
    return best_index_2

# Predict
best_index_2 = predict_spacy(nlp, query_sentence, embed_mat)
display(df[['rl','projects__name','sentence']].iloc[best_index_2])
# Out:
#       rl               projects__name  \
# 546  500  Product DMs/Business Elites
# 714  448  Product DMs/Business Elites
# 710  448  Product DMs/Business Elites
# 173  273  Product DMs/Business Elites
# 706  448  Product DMs/Business Elites
# 886  448  Product DMs/Business Elites
# 702  448  Product DMs/Business Elites
# 550  500  Product DMs/Business Elites
# 554  500  Product DMs/Business Elites
# 698  448  Product DMs/Business Elites
#
#                                                                                                                                                   sentence
# 546  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 714  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 710  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 173  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 706  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 886  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 702  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 550  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 554  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 698  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}

# %%
import sys
sys.executable
# Out:
# 'c:\\ProgramData\\Anaconda3\\python.exe'

# %%
# %pip install gensim --user
# Out:
# Collecting gensim
#   Using cached gensim-4.2.0-cp39-cp39-win_amd64.whl (23.9 MB)
# Collecting Cython==0.29.28
#   Using cached Cython-0.29.28-py2.py3-none-any.whl (983 kB)
# Requirement already satisfied: scipy>=0.18.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.7.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.20.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Installing collected packages: Cython, gensim
# Successfully installed Cython-0.29.28 gensim-4.2.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts cygdb.exe, cython.exe and cythonize.exe are installed in 'C:\Users\junaid.shaikh\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# # Word2Vec

# %%
##### WORD2VEC #####

from gensim.models.word2vec import Word2Vec

# Create model
word2vec_model = Word2Vec(min_count=0, workers = 8, vector_size=300) 
# Prepare vocab
word2vec_model.build_vocab(df.tok_lem_sentence.values)
# Train
word2vec_model.train(df.tok_lem_sentence.values, total_examples=word2vec_model.corpus_count, epochs=30)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\JUNAID~1.SHA\AppData\Local\Temp/ipykernel_12256/2519786566.py in <module>
#       1 ##### WORD2VEC #####
#       2
# ----> 3 from gensim.models.word2vec import Word2Vec
#       4
#       5 # Create model
#
# ModuleNotFoundError: No module named 'gensim'

# %%
def is_word_in_model(word, model):
    """
    Check on individual words ``word`` that it exists in ``model``.
    """
    assert type(model).__name__ == 'KeyedVectors'
    is_in_vocab = word in model.key_to_index.keys()
    return is_in_vocab

def predict_w2v(query_sentence, dataset, model, topk=3):
    query_sentence = query_sentence.split()
    in_vocab_list, best_index = [], [0]*topk
    for w in query_sentence:
        # remove unseen words from query sentence
        if is_word_in_model(w, model.wv):
            in_vocab_list.append(w)
    # Retrieve the similarity between two words as a distance
    if len(in_vocab_list) > 0:
        sim_mat = np.zeros(len(dataset))  # TO DO
        for i, data_sentence in enumerate(dataset):
            if data_sentence:
                sim_sentence = model.wv.n_similarity(
                        in_vocab_list, data_sentence)
            else:
                sim_sentence = 0
            sim_mat[i] = np.array(sim_sentence)
        # Take the five highest norm
        best_index = np.argsort(sim_mat)[::-1][:topk]
    return best_index

# Predict
best_index = predict_w2v(query_sentence, df['tok_lem_sentence'].values, word2vec_model)    
display(df[['rl','projects__name','sentence']].iloc[best_index])

# %% [markdown]
# # Transformer

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
corpus_embeddings = model.encode(df.sentence.values, convert_to_tensor=True)
query_embedding = model.encode(query_sentence, convert_to_tensor=True)
# Out:
# Downloading: 100%|██████████| 690/690 [00:00<00:00, 235kB/s]
# Downloading: 100%|██████████| 190/190 [00:00<00:00, 64.4kB/s]
# Downloading: 100%|██████████| 3.69k/3.69k [00:00<00:00, 1.85MB/s]
# Downloading: 100%|██████████| 629/629 [00:00<00:00, 157kB/s]
# Downloading: 100%|██████████| 122/122 [00:00<00:00, 64.0kB/s]
# Downloading: 100%|██████████| 229/229 [00:00<00:00, 76.4kB/s]
# Downloading: 100%|██████████| 90.9M/90.9M [00:21<00:00, 4.31MB/s]
# Downloading: 100%|██████████| 53.0/53.0 [00:00<00:00, 18.2kB/s]
# Downloading: 100%|██████████| 112/112 [00:00<00:00, 56.0kB/s]
# Downloading: 100%|██████████| 466k/466k [00:01<00:00, 400kB/s]
# Downloading: 100%|██████████| 314/314 [00:00<00:00, 105kB/s]
# Downloading: 100%|██████████| 232k/232k [00:00<00:00, 266kB/s]

# %%
import torch

# We use cosine-similarity and torch.topk to find the highest 3 scores
cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
top_results = torch.topk(cos_scores, k=10)

print("\n\n======================\n\n")
print("Query:", query_sentence)
print("\nTop 5 most similar sentences in corpus:")

for score, idx in zip(top_results[0], top_results[1]):
    score = score.cpu().data.numpy() 
    idx = idx.cpu().data.numpy()
    display(df[['rl','projects__name','sentence']].iloc[idx])
# Out:
# ======================
#
#
# Query: STANDARD_JOB_TITLE': ['Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)']
#
# Top 5 most similar sentences in corpus:
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 97, dtype: object
# rl                                                                                                                                                                  271
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 77, dtype: object
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 89, dtype: object
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 81, dtype: object
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 85, dtype: object
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 101, dtype: object
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 105, dtype: object
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 109, dtype: object
# rl                                                                                                                                                                  273
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 93, dtype: object
# rl                                                                                                                                                                  271
# projects__name                                                                                                                              Product DMs/Business Elites
# sentence          {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# Name: 73, dtype: object

# %% [markdown]
# # BERT

# %%
#### BERT #####

from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModel, pipeline
import torch
import numpy as np
from tqdm import tqdm


BERT_BATCH_SIZE = 4
MODEL_NAME = 'sentence-transformers/paraphrase-MiniLM-L6-v2'

class BertModel:
    def __init__(self, model_name, device=-1, small_memory=True, batch_size=BERT_BATCH_SIZE):
        self.model_name = model_name
        self._set_device(device)
        self.small_device = 'cpu' if small_memory else self.device
        self.batch_size = batch_size
        self.load_pretrained_model()

    def _set_device(self, device):
        if device == -1 or device == 'cpu':
            self.device = 'cpu'
        elif device == 'cuda' or device == 'gpu':
            self.device = 'cuda'
        elif isinstance(device, int) or isinstance(device, float):
            self.device = 'cuda'
        else:  # default
            self.device = torch.device(
                "cuda" if torch.cuda.is_available() else "cpu")

    def load_pretrained_model(self):
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        self.model = AutoModel.from_pretrained(self.model_name)
        device = -1 if self.device == 'cpu' else 0
        self.pipeline = pipeline('feature-extraction',
                                 model=self.model, tokenizer=self.tokenizer, device=device)

    def embed(self, data):
        """ Create the embedded matrice from original sentences """
        nb_batchs = 1 if (len(data) < self.batch_size) else len(
            data) // self.batch_size
        batchs = np.array_split(data, nb_batchs)
        mean_pooled = []
        for batch in tqdm(batchs, total=len(batchs), desc='Training...'):
            mean_pooled.append(self.transform(batch))
        mean_pooled_tensor = torch.tensor(
            len(data), dtype=float).to(self.small_device)
        mean_pooled = torch.cat(mean_pooled, out=mean_pooled_tensor)
        self.embed_mat = mean_pooled

    @staticmethod
    def mean_pooling(model_output, attention_mask):
        token_embeddings = model_output[0]
        input_mask_expanded = attention_mask.unsqueeze(
            -1).expand(token_embeddings.size()).float()
        return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

    def transform(self, data):
        if 'str' in data.__class__.__name__:
            data = [data]
        data = list(data)
        token_dict = self.tokenizer(
            data,
            padding=True,
            truncation=True,
            max_length=512,
            return_tensors="pt")
        token_dict = self.to(token_dict, self.device)
        with torch.no_grad():
            token_embed = self.model(**token_dict)
        # each of the 512 token has a 768 or 384-d vector depends on model)
        attention_mask = token_dict['attention_mask']
        # average pooling of masked embeddings
        mean_pooled = self.mean_pooling(
            token_embed, attention_mask)
        mean_pooled = mean_pooled.to(self.small_device)
        return mean_pooled
    
    def to(self, data: dict, device: str):
        """Send all values to device by calling v.to(device)"""
        data = {k: v.to(device) for k, v in data.items()}
        return data

    def predict(self, in_sentence, topk=3):
        input_vec = self.transform(in_sentence)
        mat = cosine_similarity(input_vec, self.embed_mat)
        # best cos sim for each token independantly
        best_index = extract_best_indices(mat, topk=topk)
        return best_index

# %%
# CPU training
bert_model = BertModel(model_name=MODEL_NAME, batch_size=BERT_BATCH_SIZE)
bert_model.embed(df.sentence.values)
# Out:
# Downloading: 100%|██████████| 314/314 [00:00<00:00, 164kB/s]
# Downloading: 100%|██████████| 629/629 [00:00<00:00, 206kB/s]
# Downloading: 100%|██████████| 226k/226k [00:00<00:00, 249kB/s]
# Downloading: 100%|██████████| 455k/455k [00:01<00:00, 341kB/s]
# Downloading: 100%|██████████| 112/112 [00:00<00:00, 37.3kB/s]
# Downloading: 100%|██████████| 86.7M/86.7M [00:18<00:00, 4.87MB/s]
# Training...: 100%|██████████| 827/827 [01:55<00:00,  7.19it/s]

# %%
# GPU training
bert_model_gpu = BertModel(model_name=MODEL_NAME, batch_size=BERT_BATCH_SIZE, device='cuda')
bert_model_gpu.transform(df.sentence.values)

# %%
#query_sentence = "STANDARD_JOB_TITLE': ['Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)']"
query_sentence = "STANDARD_EMPLOYMENT"
indices = bert_model.predict(query_sentence, 10)
#indices = bert_model_gpu.predict(query_sentence)
display(df[['rl','projects__name','sentence']].iloc[indices])
# Out:
#       rl               projects__name  \
# 141  273  Product DMs/Business Elites
# 482  500  Product DMs/Business Elites
# 173  273  Product DMs/Business Elites
# 458  500  Product DMs/Business Elites
# 169  273  Product DMs/Business Elites
# 826  448  Product DMs/Business Elites
# 165  273  Product DMs/Business Elites
# 454  500  Product DMs/Business Elites
# 161  273  Product DMs/Business Elites
# 157  273  Product DMs/Business Elites
#
#                                                                                                                                                   sentence
# 141  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 482  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 173  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 458  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 169  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 826  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 165  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 454  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 161  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}
# 157  {'STANDARD_JOB_TITLE': ['C-Level (e.g. CEO, CFO), Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)'], 'AGE': ['18-65']}

# %%
#query_sentence = "STANDARD_JOB_TITLE': ['Owner, Partner, President', 'Director (Group Director, Sr. Director, Director)']"
query_sentence = "STANDARD_EMPLOYMENT, STANDARD_INDUSTRY_PERSONAL"
indices = bert_model.predict(query_sentence, 10)
#indices = bert_model_gpu.predict(query_sentence)
display(df[['rl','projects__name','sentence']].iloc[indices])
# Out:
#      rl projects__name  \
# 0   528  Welding Study
# 58  528  Welding Study
# 64  528  Welding Study
# 63  528  Welding Study
# 62  528  Welding Study
# 61  528  Welding Study
# 60  528  Welding Study
# 59  528  Welding Study
# 57  528  Welding Study
# 66  528  Welding Study
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                             sentence
# 0   {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 58  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 64  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 63  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 62  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 61  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 60  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 59  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 57  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}
# 66  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Office supplies', 'Operations'], 'STANDARD_INDUSTRY_PERSONAL': ['Shipping\\/Distribution', 'Carpenting\\/Electrical installations\\/VVS', 'Transportation', 'Automotive', 'Engineering', 'Construction', 'Energy\\/Utilities\\/Oil and Gas', 'Chemicals\\/Plastics\\/Rubber', 'Aviation'], 'STANDARD_EMPLOYMENT': ['Self-employed part-time', 'Self-employed full-time', 'Employed part-time', 'Employed full-time']}

# %%
#groupby projects__name, rl,
#observe projects__client_id, projects__name, rl, target group columns,

print(df.shape)
# Out:
# (3309, 67)

# %%
df_subset = df[['projects__name', 'rl', 'sentence']]
print(df_subset.shape)
print(df_subset.info())
# Out:
# (3309, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   projects__name  3309 non-null   object
#  1   rl              3309 non-null   int64
#  2   sentence        3309 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 77.7+ KB
# None

# %%
df_subset['project_supplier_id'] = df_subset['projects__name'].map(str) + '-' + df_subset['rl'].map(str)
# Out:
# C:\Users\JUNAID~1.SHA\AppData\Local\Temp/ipykernel_2580/2281801809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['project_supplier_id'] = df_subset['projects__name'].map(str) + '-' + df_subset['rl'].map(str)

# %%
print(df_subset.head())
# Out:
#   projects__name   rl                                           sentence  \
# 0  Welding Study  528  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 1  Welding Study  528  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 2  Welding Study  528  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 3  Welding Study  528  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
# 4  Welding Study  528  {'STANDARD_B2B_DECISION_MAKER': ['Other', 'Off...
#
#   project_supplier_id
# 0   Welding Study-528
# 1   Welding Study-528
# 2   Welding Study-528
# 3   Welding Study-528
# 4   Welding Study-528

# %%
print(df_subset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   projects__name       3309 non-null   object
#  1   rl                   3309 non-null   int64
#  2   sentence             3309 non-null   object
#  3   project_supplier_id  3309 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 103.5+ KB
# None

# %%
df_subset.drop_duplicates(subset="project_supplier_id", keep=False, inplace=True, ignore_index=True)
print(df_subset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   projects__name       11 non-null     object
#  1   rl                   11 non-null     int64
#  2   sentence             11 non-null     object
#  3   project_supplier_id  11 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 480.0+ bytes
# None
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
print(df_subset)
# Out:
#                                        projects__name   rl  \
# 0   Non African American male 35-54 in Clark count...  565
# 1                    Healthcare/Skilled Trade 22-0750  271
# 2                                     AZ354_PIRR_0422  561
# 3                                     AZ354_PIRR_0422  445
# 4                                     AZ354_PIRR_0422  588
# 5                                     AZ354_PIRR_0422  341
# 6                                     AZ354_PIRR_0422  359
# 7                        information workers - 147268  565
# 8                                   OR bid 14077 auto  601
# 9                                   OR bid 14077 auto  588
# 10                                  OR bid 14077 auto  490
#
#                                              sentence  \
# 0                                  {'AGE': ['35-54']}
# 1   {'PROVINCE_OR_TERRITORY_OF_CANADA': ['Alberta'...
# 2                                  {'AGE': ['21-99']}
# 3                                  {'AGE': ['21-99']}
# 4                                  {'AGE': ['21-99']}
# 5                                  {'AGE': ['21-99']}
# 6                                  {'AGE': ['21-99']}
# 7                                  {'AGE': ['18-99']}
# 8                      {'GENDER': ['Female', 'Male']}
# 9                      {'GENDER': ['Female', 'Male']}
# 10                     {'GENDER': ['Female', 'Male']}
#
#                                   project_supplier_id
# 0   Non African American male 35-54 in Clark count...
# 1                Healthcare/Skilled Trade 22-0750-271
# 2                                 AZ354_PIRR_0422-561
# 3                                 AZ354_PIRR_0422-445
# 4                                 AZ354_PIRR_0422-588
# 5                                 AZ354_PIRR_0422-341
# 6                                 AZ354_PIRR_0422-359
# 7                    information workers - 147268-565
# 8                               OR bid 14077 auto-601
# 9                               OR bid 14077 auto-588
# 10                              OR bid 14077 auto-490
